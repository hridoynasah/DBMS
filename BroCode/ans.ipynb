# %% [markdown]
# To solve this problem, we need to determine the network block for each subnet (A, B, and C) given the IP address `172.15.0.0/16` and the number of hosts required for each subnet. We will then find the Network Address, First Host Address, Last Host Address, and Broadcast Address for each subnet.
#
# ### Step 1: Determine the Subnet Mask
#
# The given IP address is `172.15.0.0/16`, which means the first 16 bits are used for the network part, and the remaining 16 bits are available for subnetting and hosts.
#
# ### Step 2: Calculate the Number of Bits Needed for Each Subnet
#
# We need to calculate the number of bits required for the host part of each subnet based on the number of hosts needed.
#
# #### For Subnet A (1010 hosts):
#
# - The number of hosts required is 1010.
# - The formula to find the number of bits needed for hosts is $2^h - 2 \geq 1010$, where $h$ is the number of host bits.
# - Solving for $h$: $2^{10} = 1024$, so $h = 10$.
# - Therefore, the number of subnet bits needed is $16 - 10 = 6$.
#
# #### For Subnet B (508 hosts):
#
# - The number of hosts required is 508.
# - The formula to find the number of bits needed for hosts is $2^h - 2 \geq 508$, where $h$ is the number of host bits.
# - Solving for $h$: $2^9 = 512$, so $h = 9$.
# - Therefore, the number of subnet bits needed is $16 - 9 = 7$.
#
# #### For Subnet C (225 hosts):
#
# - The number of hosts required is 225.
# - The formula to find the number of bits needed for hosts is $2^h - 2 \geq 225$, where $h$ is the number of host bits.
# - Solving for $h$: $2^8 = 256$, so $h = 8$.
# - Therefore, the number of subnet bits needed is $16 - 8 = 8$.
#
# ### Step 3: Assign Subnets and Calculate Addresses
#
# We will assign the subnets in descending order of the number of bits needed for the subnet.
#
# #### Subnet A (6 bits for subnet, 10 bits for hosts):
#
# - Subnet mask: `/22` (16 + 6 = 22)
# - Network Address: `172.15.0.0`
# - First Host Address: `172.15.0.1`
# - Last Host Address: `172.15.3.254`
# - Broadcast Address: `172.15.3.255`
#
# #### Subnet B (7 bits for subnet, 9 bits for hosts):
#
# - Subnet mask: `/23` (16 + 7 = 23)
# - Network Address: `172.15.4.0`
# - First Host Address: `172.15.4.1`
# - Last Host Address: `172.15.5.254`
# - Broadcast Address: `172.15.5.255`
#
# #### Subnet C (8 bits for subnet, 8 bits for hosts):
#
# - Subnet mask: `/24` (16 + 8 = 24)
# - Network Address: `172.15.6.0`
# - First Host Address: `172.15.6.1`
# - Last Host Address: `172.15.6.254`
# - Broadcast Address: `172.15.6.255`
#
# ### Final Results:
#
# #### Subnet A:
#
# - Network Address: `172.15.0.0`
# - First Host Address: `172.15.0.1`
# - Last Host Address: `172.15.3.254`
# - Broadcast Address: `172.15.3.255`
#
# #### Subnet B:
#
# - Network Address: `172.15.4.0`
# - First Host Address: `172.15.4.1`
# - Last Host Address: `172.15.5.254`
# - Broadcast Address: `172.15.5.255`
#
# #### Subnet C:
#
# - Network Address: `172.15.6.0`
# - First Host Address: `172.15.6.1`
# - Last Host Address: `172.15.6.254`
# - Broadcast Address: `172.15.6.255`
#
# These addresses ensure that each subnet has the required number of hosts and does not overlap with other subnets.
